# %%
# #정수 :0, -1,100
# a=100
# print(a)

# # 실수형 3.145
# # 주석처리  
# a= 3.156
# print(a)

# ctrl + /

# 8진수 0o34 => 4*8^0 + 3*8^1 

# b = 0o177
# print(b) 
# print(7*8**0 +7*8**1 + 1*8**2) # * 곱하기, ** 제곱

# 16진수 ex) 0x34

#사칙연산 +, - , *, / 
a=4
b=3
# print(a+b)
# print(a-b)
# print(a*b)
# print(a/b)

# 어떤 수의 제곱 : **
3**2 #9

# 나머지를 반환 : %, 몫 반환 :  //
7%4 # 3
6%4 # 2

6//4 # 결과1
# Out:
# 1

# %%
print("hello world")
# 실행 단축키 : ctrl + enter
# Out:
# hello world

# %%
#ctrl + M + B

#문자열

# print("hello world") #""
# print('hello world') #''
# print("""hello world""") 
# print('''hello world''')

#문자열 인덱싱 - 파이썬은 0으로 시작 0123456789 
#hello 
#01234
# a="새해 복 많이 받으세요"
# print(a)
# print(a[0])
# print(a[1])
# print(a[-1]) #0부터 인덱스 3까지 출력 
# print(a[0:3]) #0:3 ==> 012
# print(a[0:4])
# # 0번째 자리수부터 4까지의 문자 출력

# print(a[3:])
# print(a[:-5]) 

# #자동차 번호판 114가 1234
# car = "114가 1234"

#문자열 포매팅 %d : 정수형, %s : 문자형
# print("나는 사과를 %d개 먹을 것이다" %5)

# print("나는 사과를 %s개 먹을 것이다" %"다섯 ")

# print("소수 : %f" %3.14123245)
# print("소수 : %4.2f" %3.14123245)

# .format(넣고 싶은 값)
# a = 5
# b = "수요일"
# print("나는 사과 {0}개를 {1}에 먹을 것이다".format(a,b))

# # 이름 : 나이 를 출력하는 문제
# name = "김수현"
# age = 29

# print()
#이름 : 김수현, 나이 : 29 

# print("love"*10)

# age = 100
# print("나의 나이는 %d 가 되었다"%(age + 1))

#count 
a = "happy"
#print(a.count('p'))

# find 위치 알려주기
a.find('a')
a.find('p')
# Out:
# 2

# %% [markdown]
# #strip , lstrip, rstrip
# # hello = "         안녕!"
# # print(hello.lstrip())
#
#
# # hello.lstrip()
#
#  # split()
#
# date = "2020-05-01"# 날짜 저장
# date.split("-") # 년, 월, 일을 따로 출력할 수 있음
#
# phone = "010-6277-9999"
# phone.split("-")
#
# #문제  :  a = "5,969,782,550" 에서 숫자만 분리하시오. split() 이용
# a = "5,969,782,550"
# a.split(",")
#
#
#
# #replace()
# a = "Life is too short"
# a.replace("is","was")

# %%
# list는 대괄호 이용 list = [a,b,c]
#a,b,c는 어떤 값이든 가질 수 있음

a=[1,2,3,4,5]
a[0]
b=["apple", "grape", "orange"]
b

#값 추가 : append()

a.append(6)
a
a.append([7,8])
a
a.insert(0,15)
a

# 값 수정 : a[0] = 10
a[0] = 10
a

# 값 삭제 : del a[0]
del a[0]
a

#리스트 연산
c = [1,2,3]
d = [4,5,6]
e = c+d
e 
e*3

#길이 구하는 함수 : len(a)
len(a)

# fruit = ["apple", "orange","banana"] 여기서 apple, orange 사이에 strawberry를 추가
fruit = ["apple", "orange","banana"]
fruit.insert(0,"grape")
fruit
fruit.insert(2,"strawberry")
fruit

# banana 삭제하기 


#정렬하기 sort()
h= [1,2,3,7,6]
h.sort()
h

#리스트 뒤집기 reverse()
h.reverse()
h

#1의 인덱스 출력하기 : index() -> 값을 입력해주어야 한다.
h.index(1)

a= [1,2,3,1,2,3]
a.remove(1)
a
#a = [2,3,1,2,3]

#요소 개수를 세는 함수 count(값)
a.count(2)
a.count(1)


a
#a = [2,3,1,2,3,[4,5]]

#extend([4,5]) =[2,3,1,2,3,4,5]
a.extend([4,5])
a

#extend와 +는 같은 의미이다.
a = a + [6,7]
a
# Out:
# [2, 3, 1, 2, 3, 4, 5, 6, 7]

# %%
# 튜플 자료형

# 튜플은 수정, 삭제 불가능
# 리스트[] 튜플 ()

list = [1]
list
tuple = (1,) # 값 하나 저장 시 콤마 붙이기
tuple

t1 = (1,2,"apple","orange")
t1[0]
t1[3]

t1[:]#전체 값 다 출력됨

t1[2:]
t1[:2] # 앞:뒤 -> 뒤에 있는 인덱스는 출력하고자 하는 인덱스+1

t2 = (3,4)
plus = t1 + t2
plus 

#같은 튜플 반복 출력 : *
#t2*3

t3 = (1,2,3) # 5를 추가해서 저장해주세요 t3 = (1,2,3,5)
t4 = (5,)
t3+t4
# Out:
# (1, 2, 3, 5)
